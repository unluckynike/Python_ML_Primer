# %%
# 1、获取数据
# 2、合并表
# 3、找到user_id和aisle之间的关系
# 4、PCA降维

# %%
import pandas as pd

# %%
# 获取数据
order_products = pd.read_csv("./instacart/order_products__prior.csv")
products = pd.read_csv("./instacart/products.csv")
orders = pd.read_csv("./instacart/orders.csv")
aisles = pd.read_csv("./instacart/aisles.csv")

# %%
order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# 2、合并表
# order_products__prior.csv：订单与商品信息

# 字段：order_id, product_id, add_to_cart_order, reordered
# products.csv：商品信息
# 字段：product_id, product_name, aisle_id, department_id
# orders.csv：用户的订单信息
# 字段：order_id,user_id,eval_set,order_number,….
# aisles.csv：商品所属具体物品类别
# 字段： aisle_id, aisle

# 合并aisles和products aisle和product_id
table1=pd.merge(aisles,products,on=["aisle_id","aisle_id"])

# %%
table1.head()
# Out:
#    aisle_id                  aisle  product_id  \
# 0         1  prepared soups salads         209
# 1         1  prepared soups salads         554
# 2         1  prepared soups salads         886
# 3         1  prepared soups salads        1600
# 4         1  prepared soups salads        2539
#
#                                         product_name  department_id
# 0                                Italian Pasta Salad             20
# 1                                       Turkey Chili             20
# 2  Whole Grain Salad with Roasted Pecans & Mango ...             20
# 3                           Mediterranean Orzo Salad             20
# 4                              Original Potato Salad             20

# %%
table2=pd.merge(table1,order_products,on=["product_id","product_id"])

# %%
table2.head()
# Out:
#    aisle_id                  aisle  product_id         product_name  \
# 0         1  prepared soups salads         209  Italian Pasta Salad
# 1         1  prepared soups salads         209  Italian Pasta Salad
# 2         1  prepared soups salads         209  Italian Pasta Salad
# 3         1  prepared soups salads         209  Italian Pasta Salad
# 4         1  prepared soups salads         209  Italian Pasta Salad
#
#    department_id  order_id  add_to_cart_order  reordered
# 0             20     94246                  5          0
# 1             20    192465                  2          1
# 2             20    195206                 18          1
# 3             20    227717                  1          1
# 4             20    260072                 13          0

# %%
table3=pd.merge(table2,orders,on=["order_id","order_id"])

# %%
table3.head() # 通过字段合并后的最终表
# Out:
#    aisle_id                  aisle  product_id  \
# 0         1  prepared soups salads         209
# 1         1  prepared soups salads       22853
# 2         4          instant foods       12087
# 3         4          instant foods       47570
# 4        13         prepared meals       10089
#
#                                product_name  department_id  order_id  \
# 0                       Italian Pasta Salad             20     94246
# 1                         Pesto Pasta Salad             20     94246
# 2          Chicken Flavor Ramen Noodle Soup              9     94246
# 3  Original Flavor Macaroni & Cheese Dinner              9     94246
# 4                                    Dolmas             20     94246
#
#    add_to_cart_order  reordered  user_id eval_set  order_number  order_dow  \
# 0                  5          0   114082    prior            26          0
# 1                  4          0   114082    prior            26          0
# ...

# %% [markdown]
# #### 透视表就是将指定原有DataFrame的列分别作为行索引和列索引，然后对指定的列应用聚集函数(默认情况下式mean函数)。交叉表是用于统计分组频率的特殊透视表

# %%
# 3、找到user_id和aisle之间的关系 交叉表
table=pd.crosstab(table3["user_id"],table3["aisle"])

# %%
table.head()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# 3                          0                  0                0
# 4                          0                  0                0
# 5                          0                  0                0
#
# aisle    baking ingredients  baking supplies decor  beauty  beers coolers  \
# user_id
# 1                         0                      0       0              0
# ...

# %%
data=table[:10000]# 取一万条数据

# %%
from sklearn.decomposition import PCA

# %%
transfer=PCA(n_components=0.95)
data_new=transfer.fit_transform(table)

# %%
data_new.shape # 由原来的134个特征降到了44个特征
# Out:
# (206209, 44)

# %% [markdown]
# #### KMeans
#    - 已经有降维的数据

# %%
data_new
# Out:
# array([[-24.21565874,   2.4294272 ,  -2.46636975, ...,  -0.08877715,
#          -0.38087761,   0.21568831],
#        [  6.46320808,  36.75111646,   8.38255336, ...,   1.912145  ,
#           1.79468946,  -0.70142249],
#        [ -7.99030162,   2.40438257, -11.03006405, ...,  -0.72188348,
#          -1.15719089,  -0.23704277],
#        ...,
#        [  8.61143331,   7.70129866,   7.95240226, ...,   0.23971061,
#          -0.78590175,  -2.65945606],
#        [ 84.08621987,  20.41873398,   8.05410372, ...,  -1.66893212,
#           0.5042934 ,   3.82546312],
#        [-13.95345619,   6.64621821,  -5.23030367, ...,  -1.64144758,
#          -3.39233648,  -0.31410713]])

# %%
from sklearn.cluster import KMeans

# %%
estimator=KMeans(n_clusters=3)
estimator.fit(data_new)# 没有目标值
# Out:
# KMeans(n_clusters=3)

# %%
y_predict=estimator.predict(data_new)

# %%
y_predict[:300] # 分成了 0 1 2 三类
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2,
#        1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1,
#        2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        1, 2, 2, 2, 2, 2, 2, 0, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1,
#        1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2,
#        2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 1, 2,
#        1, 2, 0, 2, 2, 2, 1, 2, 2, 2, 2, 1, 1, 1, 2, 1, 2, 2, 2, 2, 2, 2,
#        1, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 0,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2,
# ...

# %%
# 模型评估-轮廓系数
from sklearn.metrics import silhouette_score

# %%
silhouette_score(data_new,y_predict)
